# %%
import pandas as pd
import numpy as np

# %%
from env import host, user, password

url = f'mysql+pymysql://{user}:{password}@{host}/employees'

# %% [markdown]
# ### Create a function named get_db_url. It should accept a username, hostname, password, and database name and return a url connection string formatted like in the example at the start of this lesson.

# %%
# def get_db_url(username, hostname, password, database):
#     url = f'mysql+pymysql://{user}:{password}@{host}/{database}'
#     return url

#defines function to create a sql url using personal credentials
def get_db_url(db_name):
    
    #importing variables used to connect to sql database
    from env import host, user, password
    
    #creates the url and the function returns it
    url = f'mysql+pymysql://{user}:{password}@{host}/{db_name}'
    return (url)

# %%
# get_db_url(user, host, password, 'employees')

# get_db_url("employees")

pd.read_sql('SELECT * FROM employees LIMIT 5 OFFSET 50', get_db_url('employees'))
# Out:
#    emp_no  birth_date first_name  last_name gender   hire_date
# 0   10051  1953-07-28   Hidefumi      Caine      M  1992-10-15
# 1   10052  1961-02-26     Heping     Nitsch      M  1988-05-21
# 2   10053  1954-09-13     Sanjiv   Zschoche      F  1986-02-04
# 3   10054  1957-04-04     Mayumi  Schueller      M  1995-03-13
# 4   10055  1956-06-06     Georgy     Dredge      M  1992-04-27

# %%
# Create the users DataFrame.

users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
# Create the roles DataFrame

roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %% [markdown]
# ### What is the result of using a right join on the DataFrames?
#
# ### What is the result of using an outer join on the DataFrames?

# %%
# right join:
#default concat first:

pd.concat([users, roles])
# Out:
#    id       name  role_id
# 0   1        bob      1.0
# 1   2        joe      2.0
# 2   3      sally      3.0
# 3   4       adam      3.0
# 4   5       jane      NaN
# 5   6       mike      NaN
# 0   1      admin      NaN
# 1   2     author      NaN
# 2   3   reviewer      NaN
# 3   4  commenter      NaN

# %%
join_right = users.merge(roles, left_on='role_id', right_on='id', how='right', indicator=True)

join_right
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0     1      admin        both
# 1   2.0    joe      2.0     2     author        both
# 2   3.0  sally      3.0     3   reviewer        both
# 3   4.0   adam      3.0     3   reviewer        both
# 4   NaN    NaN      NaN     4  commenter  right_only

# %%
# outer join: 

join_outer = users.merge(roles, left_on='role_id', right_on='id', how='outer', indicator=True)

join_outer
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0   1.0      admin        both
# 1   2.0    joe      2.0   2.0     author        both
# 2   3.0  sally      3.0   3.0   reviewer        both
# 3   4.0   adam      3.0   3.0   reviewer        both
# 4   5.0   jane      NaN   NaN        NaN   left_only
# 5   6.0   mike      NaN   NaN        NaN   left_only
# 6   NaN    NaN      NaN   4.0  commenter  right_only

# %% [markdown]
# ### What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
no_foreign_keys = (users.merge(roles, left_on='role_id', right_on='id', how='right', indicator=True)
                        .drop(columns = 'role_id')
                        .rename(columns={'id_x': 'id', 
                                         'name_x': 'employee',
                                         'id_y': 'role_id',
                                         'name_y': 'role'}
                                            ))

no_foreign_keys
# Out:
#     id employee  role_id       role      _merge
# 0  1.0      bob        1      admin        both
# 1  2.0      joe        2     author        both
# 2  3.0    sally        3   reviewer        both
# 3  4.0     adam        3   reviewer        both
# 4  NaN      NaN        4  commenter  right_only

# %% [markdown]
# ### Load the mpg dataset from PyDataset.
#
# ### Output and read the documentation for the mpg dataset.
#
# ### How many rows and columns are in the dataset?

# %%
from pydataset import data

# %%
mpg = data('mpg', show_doc = True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
mpg.shape
# Out:
# (234, 11)

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# ### Check out your column names and perform any cleanup you may want on them.
#
# ### Display the summary statistics for the dataset.
#
# ### How many different manufacturers are there?
#
# ### How many different models are there

# %%
mpg.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
mpg.groupby('manufacturer').manufacturer.count()
#how many manufacturers are there, I first grouped by manufacturer, then count how many rows
# Out:
# manufacturer
# audi          18
# chevrolet     19
# dodge         37
# ford          25
# honda          9
# hyundai       14
# jeep           8
# land rover     4
# lincoln        3
# mercury        4
# nissan        13
# pontiac        5
# subaru        14
# toyota        34
# volkswagen    27
# Name: manufacturer, dtype: int64

# %%
(mpg.groupby('manufacturer').manufacturer.count()).count()
# Out:
# 15

# %%
(mpg.groupby('model').model.count()).count()
#how many models are there, I first grouped by model, then count how many rows

# %% [markdown]
# ### Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = (mpg.hwy - mpg.cty)

mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    mileage_difference
# 1                  11
# 2                   8
# 3                  11
# 4                   9
# 5                  10

# %% [markdown]
# ### Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
mpg["average_mileage"] = ((mpg.hwy + mpg.cty)/2)

mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    mileage_difference  average_mileage
# 1                  11             23.5
# 2                   8             25.0
# 3                  11             25.5
# 4                   9             25.5
# 5                  10             21.0

# %% [markdown]
# ### Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
mpg["is_automatic"] = np.where(mpg.trans.str.contains('auto'), True, False)

# df['passing_math'] = np.where(df.math < 70, 'failing', 'passing')
# df

mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    mileage_difference  average_mileage  is_automatic
# 1                  11             23.5          True
# 2                   8             25.0         False
# 3                  11             25.5         False
# 4                   9             25.5          True
# 5                  10             21.0          True

# %% [markdown]
# ### Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
#group by manufacturer - average mileage

# Here's an example from the lesson: df.groupby('classroom').math.agg(['min', 'mean', 'max'])
# Let's apply it here:

mileage_by_manufacturer = mpg.groupby('manufacturer').average_mileage.agg(['mean'])

mileage_by_manufacturer
# Out:
#                    mean
# manufacturer
# audi          22.027778
# chevrolet     18.447368
# dodge         15.540541
# ford          16.680000
# honda         28.500000
# hyundai       22.750000
# jeep          15.562500
# land rover    14.000000
# lincoln       14.166667
# mercury       15.625000
# nissan        21.346154
# pontiac       21.700000
# subaru        22.428571
# toyota        21.720588
# volkswagen    25.074074

# %%
# Now, let's sort the mileage column:

mileage_by_manufacturer.sort_values(by = 'mean', ascending = False)
# Out:
#                    mean
# manufacturer
# honda         28.500000
# volkswagen    25.074074
# hyundai       22.750000
# subaru        22.428571
# audi          22.027778
# toyota        21.720588
# pontiac       21.700000
# nissan        21.346154
# chevrolet     18.447368
# ford          16.680000
# mercury       15.625000
# jeep          15.562500
# dodge         15.540541
# lincoln       14.166667
# land rover    14.000000

# %%
#we can chain the method for the top now to get the max

mileage_by_manufacturer.sort_values(by = 'mean', ascending = False).head(1)
# Out:
#               mean
# manufacturer
# honda         28.5

# %% [markdown]
# ### Do automatic or manual cars have better miles per gallon?

# %% [markdown]
# ## Exercises Part III

# %% [markdown]
# 1. Use your get_db_url function to help you explore the data from the chipotle database.
#
# 2. What is the total price for each order?
#
# 3. What are the most popular 3 items?
#
# 4. Which item has produced the most revenue?
#
# 5. Join the employees and titles DataFrames together.
#
# 6. For each title, find the hire date of the employee that was hired most recently with that title.
#
# 7. Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

# %% [markdown]
# using this function from above:
#
# def get_db_url(db_name):
#     from env import host, user, password
#     url = f'mysql+pymysql://{user}:{password}@{host}/{db_name}'
#     return (url)

# %%
#create a df named 'orders' that is from the SQL table 'orders' w/in the SQL db 'chipotle'
orders = pd.read_sql('SELECT * FROM orders', get_db_url('chipotle'))
orders
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
orders.item_price
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
#need to take away the $
orders['float_price'] = orders.item_price.str.replace('$','').astype(float)
orders
# Out:
# <ipython-input-80-19d088519a5f>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   orders['float_price'] = orders.item_price.str.replace('$','').astype(float)
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# ...

# %%
orders.float_price.agg('sum')
# Out:
# 34500.16

# %%
orders.groupby('item_name').item_name.count().nlargest(3)
# Out:
# item_name
# Chicken Bowl           726
# Chicken Burrito        553
# Chips and Guacamole    479
# Name: item_name, dtype: int64

# %%
orders.groupby('item_name').quantity.agg('sum').nlargest(3)
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Name: quantity, dtype: int64

# %%
# employees_titles.groupby(by = 'title').hire_date.max()
